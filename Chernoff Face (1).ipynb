# %%
#To install ChernoffFace
# pip install ChernoffFace

# %%
# import the required packages
from ChernoffFace import *
import numpy
import matplotlib.cm
import pandas as pd
import numpy as np

# %%
# import the data
df=pd.read_csv("students_placement_data1.csv");
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2              65.00        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
# Select only required columns
df=df[['SSC Percentage','inter_Diploma_percentage','B.Tech_percentage']]

# %%
# Normalize the data
df=variables_rescale(df)
df
# Out:
#      SSC Percentage  inter_Diploma_percentage  B.Tech_percentage
# 0          0.871929                  0.442681           0.281016
# 1          0.906162                  0.920635           0.000000
# 2          0.463149                  0.000000           0.654709
# 3          0.543697                  0.532628           0.228251
# 4          0.000000                  0.446208           0.318685
# ..              ...                       ...                ...
# 112        0.747080                  0.677249           0.218834
# 113        0.751108                  0.792240           0.707025
# 114        0.795409                  0.876543           0.823617
# 115        0.835683                  0.889418           0.796712
# 116        0.724930                  0.760670           0.662631
#
# [117 rows x 3 columns]

# %%
# for simplicity select first 16 rows
df_16=df.head(16)
df_16
# Out:
#     SSC Percentage  inter_Diploma_percentage  B.Tech_percentage
# 0         0.871929                  0.442681           0.281016
# 1         0.906162                  0.920635           0.000000
# 2         0.463149                  0.000000           0.654709
# 3         0.543697                  0.532628           0.228251
# 4         0.000000                  0.446208           0.318685
# 5         0.463149                  0.490300           0.612855
# 6         0.543697                  0.287478           0.187892
# 7         0.822191                  0.689594           0.595217
# 8         0.825614                  0.871252           0.475336
# 9         0.805477                  0.622575           0.445441
# 10        0.771849                  0.636684           0.751719
# 11        0.946436                  0.455026           0.425561
# 12        0.751712                  0.354497           0.501345
# 13        0.867902                  0.855379           0.803587
# 14        0.384615                  0.211640           0.438714
# 15        0.842328                  0.807760           0.818535

# %%
# Apply the function
fig = chernoff_face(data=df_16, n_columns=4)
